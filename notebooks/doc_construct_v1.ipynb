# %%
import os
import sys
import time
import base64
import uuid
import pandas as pd
from zipfile import ZipFile
from lxml import etree
import xml.etree.ElementTree as ET
import codecs
import json
from itertools import groupby

utilities_dir = '/Users/kd/Workspace/python/helpers'
sys.path.append(utilities_dir)

from file_directory_utils import (create_directory, read_directory_files, get_subdirectories, get_all_file_paths)

# %%
input_filepath = '/Users/kd/Workspace/python/DOCX/document-formatting/data/input/demo_judgment_1.docx'
output_dir     = '/Users/kd/Workspace/python/DOCX/document-formatting/data/output'

fetch_content_filepath = '/Users/kd/Workspace/python/DOCX/document-formatting/data/input/demo_judgment_1.json'
filename       = os.path.splitext(os.path.basename(input_filepath))[0]

# %%
def get_string_xmltree(xml):
    return etree.tostring(xml)

def get_xml_tree(xml_string):
    return etree.fromstring(xml_string)

def get_xmltree(filepath, parse='xml'):
    if parse == 'html':
        parser = etree.HTMLParser()
        tree   = etree.parse(open(filepath, mode='r', encoding='utf-8'), parser)
        return tree
    else:
        with open(filepath,'r') as file:
            xml_string    = file.read()
            return etree.fromstring(bytes(xml_string, encoding='utf-8'))
    return None

def check_element_is(element, type_char):
    word_schema1 = "http://schemas.openxmlformats.org/wordprocessingml/2006/main"
    word_schema2 = 'http://purl.oclc.org/ooxml/wordprocessingml/main'
     
    return (element.tag == '{%s}%s' % (word_schema1, type_char)) or (element.tag == '{%s}%s' % (word_schema2, type_char))

def get_specific_tags(node, type_char):
    nodes = []
    for elem in node.iter():
        if check_element_is(elem, type_char):
            nodes.append(elem)
    return nodes

def add_identifier(node):
    node.attrib['id'] = str(uuid.uuid4())

def is_run_superscript(run):
    attrib    = {}
    vertAlign = get_specific_tags(run, 'vertAlign')
    if len(vertAlign) > 0:
        for key in vertAlign[0].attrib.keys():
            attrib['vertAlign_' + key.split('}')[-1]] = vertAlign[0].attrib[key]
    if 'vertAlign_val' in attrib:
        if attrib['vertAlign_val'] == 'superscript':
            return True
    return False
    
def update_run_text(r1, r2):
    t1s = get_specific_tags(r1, 't')
    t2s = get_specific_tags(r2, 't')
#     print('r1 text [%s], r2 text [%s]'% (t1s[0].text, t2s[0].text))
    t1s[0].text = t1s[0].text + t2s[0].text
    t2s[0].text = ''
    
def get_run_properties(run):
    attrib = {}
    rFonts = get_specific_tags(run, 'rFonts')
    sz     = get_specific_tags(run, 'sz')
    szCs   = get_specific_tags(run, 'szCs')
    
    if len(rFonts) > 0:
        for key in rFonts[0].attrib.keys():
            attrib['rFonts_' + key.split('}')[-1]] = rFonts[0].attrib[key]
    
    if len(sz) > 0:
        for key in sz[0].attrib.keys():
            attrib['sz_' + key.split('}')[-1]] = sz[0].attrib[key]
        
    if len(szCs) > 0:
        for key in szCs[0].attrib.keys():
            attrib['szCs_' + key.split('}')[-1]] = szCs[0].attrib[key]

    return attrib

def compare_run_properties(run1, run2):
    attrib1 = get_run_properties(run1)
    attrib2 = get_run_properties(run2)
    
    if all (k in attrib1 for k in ('rFonts_ascii', 'sz_val', 'szCs_val')):
        if all (k in attrib2 for k in ('rFonts_ascii', 'sz_val', 'szCs_val')):
            if (attrib1['rFonts_ascii'] == attrib2['rFonts_ascii']) and \
            (attrib1['szCs_val'] == attrib2['szCs_val']) and \
            (attrib1['sz_val'] == attrib2['sz_val']) :
                return True
    
    return False

def get_line_connections(p):
    runs             = get_specific_tags(p, 'r')
    text_runs        = []
    
    for run in runs:
        if is_run_superscript(run) == False:
            text_runs.append(run)

    line_connections = []
    for index in range(len(text_runs) - 1):
        if (compare_run_properties(text_runs[index], text_runs[index+1])):
            line_connections.append((index, index+1, 'CONNECTED'))
        else:
            line_connections.append((index, index+1, 'NOT_CONNECTED'))
    return line_connections

def arrange_grouped_line_indices(line_connections, debug=False):
    lines          = [list(i) for j, i in groupby(line_connections, lambda a: a[2])]
    if debug:
        print('arrange_grouped_line_indices: %s \n---------\n' % (str(lines)))
        
    arranged_lines = []

    for line_items in lines:
        indices = []
        for line_item in line_items:
            indices.append(line_item[0])
            indices.append(line_item[1])
        indices = sorted(list(set(indices)))
        arranged_lines.append([indices, line_items[0][2]])
        
    if debug:
        print('arrange_grouped_line_indices,arranged_lines : %s \n---------\n' % (str(arranged_lines)))
    
    final_arranged_lines = []
    
    if len(arranged_lines) == 1:
        final_arranged_lines.append([arranged_lines[0][0], arranged_lines[0][1]])
    else:
        for index, line_item in enumerate(arranged_lines):
            if index == 0 and line_item[1] == 'NOT_CONNECTED':
                del line_item[0][-1]
            if index > 0 and index < (len(arranged_lines) - 1) and line_item[1] == 'NOT_CONNECTED':
                del line_item[0][0]
                del line_item[0][-1]
            if index == (len(arranged_lines) - 1) and line_item[1] == 'NOT_CONNECTED':
                del line_item[0][0]

            final_arranged_lines.append([line_item[0], line_item[1]])
    if debug:
        print('final_arrange_grouped_line_indices,arranged_lines : %s \n---------\n' % (str(final_arranged_lines)))
            
    return final_arranged_lines

def merge_runs(node, grouped_runs, debug=False):
    runs      = get_specific_tags(node, 'r')
    text_runs = []
    
    for run in runs:
        if is_run_superscript(run) == False:
            text_runs.append(run)

    for element in grouped_runs:
        if (element[1] == 'CONNECTED'):
            for index, run_index in enumerate(element[0]):
                if (index > 0):
                    if (debug):
                        print('merge index %d with %d' % ( run_index, 0))
                    update_run_text(text_runs[0], text_runs[run_index])
                    
def update_document_runs(document):
    '''
    the function iterates through the p tags and merges run that have exactly same
    visual property.
    '''
    tag_name                 = 'p'
    tags                     = get_specific_tags(document, tag_name)
    for p in tags:
        grouped_runs = arrange_grouped_line_indices(get_line_connections(p))
        merge_runs(p, grouped_runs, debug=False)
    return document

def get_text_tags(document):
    tags         = []
    texts        = get_specific_tags(document, 't')
    for text in texts:
        if text.text and len(text.text.strip()) > 0:
            add_identifier(text)
            tags.append(text)
    return tags

# %%
def extract_docx(filepath, working_dir):
    filename       = os.path.splitext(os.path.basename(filepath))[0]
    extract_dir    = os.path.join(working_dir, filename)
    
    with ZipFile(filepath, 'r') as file:
        file.extractall(path=extract_dir)
        filenames = file.namelist()
    
    return extract_dir, filenames

def save_docx(extracted_dir, filenames, output_filename):
    with ZipFile(output_filename, 'w') as docx:
        for filename in filenames: 
            docx.write(os.path.join(extracted_dir, filename), filename)
            
def save_document_xml(extracted_dir, xml):
    with open(os.path.join(extracted_dir,'word/document.xml'), 'wb') as f:
        xmlstr = get_string_xmltree(xml)
        f.write(xmlstr)

# %%
def get_tokenized_sentences(filepath):
    from jsonpath_rw import jsonpath, parse
    json_data     = json.load(codecs.open(fetch_content_filepath, 'r', 'utf-8-sig'))
    jsonpath_expr = parse('$..tokenized_sentences[*]')
    matches       = jsonpath_expr.find(json_data)

    tokenized_sentences = []
    for match in matches:
        tokenized_sentences.append(match.value)
    
    return tokenized_sentences

# %%
def count_occurrences(string, substring): 
    count = 0
    start = 0
    while start < len(string): 
        pos = string.find(substring, start) 

        if pos != -1: 
            start = pos + 1
            count += 1
        else: 
            break
    return count 

def check_string_status(doc_tag, tokenized):
    doc_text       = doc_tag.text.replace(" ", "")
    tokenized_text = tokenized['src'].replace(" ", "")
    
    if len(doc_text) < 2 or len(tokenized_text) < 2:
        if doc_text.isdigit() == False or tokenized_text.isdigit() == False:
            return (False, False)
    
    '''
        perfect match
    '''
    if doc_text == tokenized_text:
        return (True, 0)
    
    count         = 0
    if len(doc_text) > len(tokenized_text):
        count = count_occurrences(doc_text, tokenized_text)
        if count != 0:
            return (True, -1)
    else:
        count = count_occurrences(tokenized_text, doc_text)
        if count != 0:
            return (True, 1)
    
    return (False, False)

# %%
def get_as_df(tags, tokenized_sentences):
    doc_texts = []
    doc_ids   = []
    for tag in tags:
        doc_texts.append(tag.text)
        doc_ids.append(tag.attrib['id'])

    tokenized_src_texts = []
    tokenized_tgt_texts = []
    for tokenized_sentence in tokenized_sentences:
        tokenized_src_texts.append(tokenized_sentence['src'])
        tokenized_tgt_texts.append(tokenized_sentence['tgt'])

    if len(doc_texts) > len(tokenized_src_texts):
        empty = [''] * (len(doc_texts) - len(tokenized_src_texts))
        tokenized_src_texts.extend(empty)
        tokenized_tgt_texts.extend(empty)
    else:
        empty = [''] * (len(tokenized_src_texts) - len(doc_texts))
        doc_texts.extend(empty)
        doc_ids.extend(empty)

    df = pd.DataFrame(list(zip(doc_texts, doc_ids, tokenized_src_texts, tokenized_tgt_texts)), 
                                  columns =['doc_texts', 'doc_ids', 'tokenized_src_texts', 'tokenized_tgt_texts'])
    return df

# %%
def replace_translated(placeholders, texts):
    for placeholder in placeholders:
        for text in texts:
            if 'id' in text.attrib:
                if text.attrib['id'] == placeholder['id']:
                    text.text = placeholder['tgt']

# %%
extracted_dir, filenames = extract_docx(input_filepath, output_dir)

# %%
document_xml             = get_xmltree(os.path.join(extracted_dir, 'word', 'document.xml'))
document_xml             = update_document_runs(document_xml)
texts                    = get_text_tags(document_xml)

tokenized_sentences      = get_tokenized_sentences(fetch_content_filepath)
print('document has (%d) text tags, tokenized sentences (%d)' % (len(texts), len(tokenized_sentences)))
# Out:
# document has (54) text tags, tokenized sentences (46)

# %%
df = get_as_df(texts, tokenized_sentences)
df.head(60)
# Out:
#                                             doc_texts  \
# 0                                          Reportable
# 1                       IN THE SUPREME COURT OF INDIA
# 2                        CIVIL APPELLATE JURISDICTION
# 3                  Civil Appeal Nos 9367-9369 of 2011
# 4                  The Secretary, Ministry of Defence
# 5                                        ...Appellant
# 6                                              Versus
# 7                                Babita Puniya & Ors.
# 8                                      ...Respondents
# 9                                                With
# 10                 Civil Appeal Nos 1127-1128 of 2013
# 11                                           And With
# 12                      Civil Appeal No. 1210 of 2020
# 13                             Signature Not Verified
# 14                                Digitally signed by
# 15                                       SANJAY KUMAR
# 16                                   Date: 2020.02.17
# 17                                       13:49:23 IST
# 18                                            Reason:
# 19                                                  1
# 20                                           JUDGMENT
# 21                     Dr Dhananjaya Y Chandrachud, J
# 22                                              Index
# 23                          Background of the dispute
# 24                     Proposal of the Union of India
# 25                                        Submissions
# 26  Consequence of the policy letter dated 25 Febr...
# 27          Stereotypes and women in the Armed Forces
# 28                      Consequence of non-compliance
# 29       Blanket restriction on criteria appointments
# 30                                         Directions
# 31                                                  2
# 32                                             PART A
# 33                                                  A
# 34                          Background of the dispute
# 35  A quest for equality of opportunity for women ...
# 36                                                  1
# 37  A decade and more spent in litigation, women e...
# 38                                                  2
# 39                                                  3
# 40  “12. Ineligibility of females for enrolment or...
# 41  Pursuant to the power conferred by Section 12,...
# 42                                                  4
# 43                                               “(i)
# 44                               Army Postal Service;
# 45               Judge Advocate General‟s Department;
# 46                              Army Education Corps;
# 47  Army Ordinance Corps (Central Ammunition Depot...
# 48   Army Service Corps (Food Scientists and Catering
# 49                                        Officers).”
# 50                                               “PC”
# 51                                             “SSCs”
# 52                                         “1950 Act”
# 53                                               SRO-
#
#                                  doc_ids  \
# 0   b9094355-2157-4399-8977-bdf6a2c00cf3
# 1   cdf87c88-9b77-4c2d-82cc-cb570d1c2f1b
# 2   011e55e0-09a9-4373-97a3-593b864d287b
# 3   0c44e697-6384-49dc-ae01-b090c8dac730
# 4   d1cc1bb9-2050-4f10-a3bc-3167fd590d01
# 5   034c6aaf-6150-4578-8b89-8adcd1c0bfc3
# 6   fc244334-ac68-4743-aa48-733454d14a0f
# 7   d0a6c4e6-b373-4704-b317-c0f97eb73c8d
# 8   e278a839-b7d4-451e-921e-83f79007d425
# 9   13755d7d-8f1f-4034-83e4-d159cfe01e3e
# 10  0b99363c-b6e9-499f-b5aa-9bcfeff04af5
# 11  8e2beeb7-3f45-4cee-81ac-7cc34f335736
# 12  a1b44059-75ee-471d-9bc3-bcb07a181907
# 13  c8b04270-9e11-4f8a-a344-ea30f7614a70
# 14  3d734258-4da1-4672-b9bf-eb958f0b5996
# 15  54254ef5-0728-47d3-8416-46ae8801d19f
# 16  d8fab517-c851-4c2c-bb6a-9b586f02b275
# 17  f86be697-4414-4bde-95c6-a5c0295e8b0b
# 18  e96004af-a0ba-49e2-b195-5aa38abe328f
# 19  9c0f46ba-1b7e-4ed8-bf36-8772d9aa5ed4
# 20  dca5cd0e-a883-4f12-be07-d92ce0463d42
# 21  24b924b8-4b24-4272-a38a-7762245ad0a9
# 22  a5126a9b-1cb5-40cc-9e9c-09d4091131b2
# 23  420039e4-1f00-4e1e-9bb8-055000deba2b
# 24  365ffc44-a486-40f8-b706-828c7ca2a958
# 25  2177cf20-a996-4b27-ac8b-0a8549fb1a47
# 26  653b50ae-c5ae-444e-9442-b6e48590902c
# 27  b5240c70-1bcb-405d-ae41-af47e1dcd240
# 28  0a3d8d38-1846-49b0-8fc3-25673e842f2c
# 29  59b80289-d09a-42cd-9854-f969213a708b
# 30  07bc0a9e-73db-4304-88d3-6503ad0cc302
# 31  ed9f4ad1-d34a-4298-9950-e7a14d03c489
# 32  48e8a9f3-b605-4db4-920b-1f5364a0242f
# 33  213b443e-b062-4e0a-a639-32ed8e2a2f6f
# 34  59f5dfad-0293-4e86-935f-15f1d5d5c11d
# 35  89107fd8-fe63-43df-bce3-c8bd7cf2fd8f
# 36  85bc8b73-ec0b-4cf7-99d8-4a7da5e77932
# 37  42d8c291-1197-4623-bb53-15eaa1c77c8a
# 38  7c94d736-aa68-4c5c-aad7-d9179aee1481
# 39  8c9028ca-0ee6-475a-84e5-5f297ff21691
# 40  75eba092-6123-4b54-9fc6-d472cf9e734c
# 41  cfba272a-534b-4044-a11f-4f902588b83d
# 42  0bc8bad8-f19c-46bc-bd6a-0b7ae3958d1c
# 43  a7939d8a-b165-4aac-ac7c-0a3ae6128a19
# 44  2cce41d7-358f-496a-b701-b678beabc6f4
# 45  30d23055-f2bb-45f0-a557-013634f64faa
# 46  a0addc4f-7c9f-4a58-9f85-d51a33e5aeed
# 47  68408be2-3253-41af-bf08-63eff0c31ae2
# 48  14486e95-2382-48ff-9556-dfff654c2bf0
# 49  c542e8fb-799a-468f-9693-5a730bcb7dff
# 50  13a9492f-3341-4cae-8301-a45b63fa8e80
# 51  6ce1b6e5-29ec-4a6e-a2d4-de711e66de1b
# 52  1e2bdab1-855e-4ccc-acc6-17e3ea980aa9
# 53  6a7b9098-58c4-43ca-85d5-dab5ca2e427e
#
#                                   tokenized_src_texts  \
# 0                                          Reportable
# 1                       IN THE SUPREME COURT OF INDIA
# 2                        CIVIL APPELLATE JURISDICTION
# 3                  Civil Appeal Nos 9367-9369 of 2011
# 4                  The Secretary, Ministry of Defence
# 5                                     ......Appellant
# 6                                              Versus
# 7                                Babita Puniya & Ors.
# 8                                   ......Respondents
# 9                                                With
# 10                 Civil Appeal Nos 1127-1128 of 2013
# 11                                           And With
# 12                      Civil Appeal No. 1210 of 2020
# 13         Signature Not Verified Digitally signed by
# 14                                       SANJAY KUMAR
# 15                                   Date: 2020.02.17
# 16                               13:49:23 IST Reason:
# 17                                                  1
# 18                                           JUDGMENT
# 19                     Dr Dhananjaya Y Chandrachud, J
# 20                                              Index
# 21                        A Background of the dispute
# 22                   B Proposal of the Union of India
# 23                                      C Submissions
# 24  D Consequence of the policy letter dated 25 Fe...
# 25        E Stereotypes and women in the Armed Forces
# 26                    F Consequence of non-compliance
# 27     G Blanket restriction on criteria appointments
# 28                                       H Directions
# 29                        A Background of the dispute
# 30                                                  2
# 31                                             PART A
# 32  1. A quest for equality of opportunity for wom...
# 33  The lead appeal originated in a batch of Writ ...
# 34  2. A decade and more spent in litigation, wome...
# 35  Section 12 of the Army Act 1950 contains, in s...
# 36  “12. Ineligibility of females for enrolment or...
# 37  3. Pursuant to the power conferred by Section ...
# 38                                        These were:
# 39  “(i) Army Postal Service; (ii) Judge Advocate ...
# 40  (iv) Army Ordinance Corps (Central Ammunition ...
# 41  (v) Army Service Corps (Food Scientists and Ca...
# 42                                             1 “PC”
# 43                                           2 “SSCs”
# 44                                       3 “1950 Act”
# 45                                             4 SRO-
# 46
# 47
# 48
# 49
# 50
# 51
# 52
# 53
#
#                                   tokenized_tgt_texts
# 0                                       रिपोर्ट योग्य
# 1                       भारत के सर्वोच्च न्यायालय में
# 2                         दीवानी अपीलीय क्षेत्राधिकार
# 3                   9367 की दीवानी अपील सं. 2011-9369
# 4                              रक्षा मंत्रालय के सचिव
# 5                                    ...... अपीलार्थी
# 6                                               बनाम
# 7                              बबिता पुनिया और ओआरएस।
# 8                                     ..... उत्तरदाता
# 9                                            साथ में
# 10                  2013 की दीवानी अपील सं. 1127-1128
# 11                                        और साथ में
# 12                       2020 की दीवानी अपील सं. 1210
# 13  हस्ताक्षर निर्दिष्ट डिजिटल रूप से हस्ताक्षरित ...
# 14                                         संजय कुमार
# 15                                 दिनांक: 2020.02.17
# 16                                 13:49:23 IST कारण:
# 17                                                  1
# 18                                            निर्णय
# 19                         डॉ धनंजय वाई चंद्रचूड़, जे
# 20                                        अनुक्रमणिका
# 21                             ए. विवाद की पृष्ठभूमि.
# 22                            बी भारत संघ के प्रस्ताव
# 23                                  स.  प्रस्तुत करना
# 24   डी.  दिनांक 25 फरवरी 2019 के नीति पत्र का परिणाम
# 25        इ. सशस्त्र सेना में ई स्टिरोटाइप और महिलाएं
# 26                            फ.  गैर-उपयोग के परिणाम
# 27             जी. ब्लैंकेट ने मानदंडों पर भरोसा किया
# 28                                          ह. दिशाएँ
# 29                             अ. विवाद की पृष्ठभूमि.
# 30                                                  2
# 31                                              भाग ए
# 32  1. भारतीय सेना में स्थायी आयोगों की मांग करने ...
# 33  लीड अपील रिट याचिकाओं के एक बैच में उत्पन्न हु...
# 34  2. मुकदमेबाजी में एक दशक से अधिक समय लगता है, ...
# 35  सेना अधिनियम 1950 की धारा 12 में, जहां तक यह स...
# 36  12. नामांकन या नियोजन के लिए महिलाओं की अयोग्य...
# 37  3. धारा 12 द्वारा प्रदत्त शक्ति के अनुसार, कें...
# 38                                             ये थे:
# 39  '(i) सेना डाक सेवा; (ii) न्यायाधीश महाधिवक्ता ...
# 40  (iv) सेना अध्यादेश कोर (केंद्रीय गोला बारूद डि...
# 41  (v) सेना सेवा कोर (खाद्य वैज्ञानिक और खानपान अ...
# 42                                          1 पी. सी.
# 43                                           2 एसएससी
# 44                                     3 1950 अधिनियम
# 45                                             4 SRO
# 46
# 47
# 48
# 49
# 50
# 51
# 52
# 53

# %%
## re-attempt
matched_ids    = []
matched_sids   = []

perfect_match   = []
tokenized_match = []
text_match      = []


for sent_index in range(len(tokenized_sentences)):
    for text_index in range(len(texts)):
        if (texts[text_index].attrib['id'] not in matched_ids) and \
        (tokenized_sentences[sent_index]['s_id'] not in matched_sids):
            is_found, is_substring = check_string_status(texts[text_index], tokenized_sentences[sent_index])
            
            if is_found and is_substring == 0:
                matched_ids.append(texts[text_index].attrib['id'])
                matched_sids.append(tokenized_sentences[sent_index]['s_id'])
                perfect_match.append({
                    's_id': tokenized_sentences[sent_index]['s_id'],
                    'src': tokenized_sentences[sent_index]['src'],
                    'tgt': tokenized_sentences[sent_index]['tgt'],
                    'id': texts[text_index].attrib['id'],
                    'text': texts[text_index].text
                })
                
            if is_found and is_substring < 0:
                tokenized_match.append({
                    's_id': tokenized_sentences[sent_index]['s_id'],
                    'src': tokenized_sentences[sent_index]['src'],
                    'tgt': tokenized_sentences[sent_index]['tgt'],
                    'id': texts[text_index].attrib['id'],
                    'text': texts[text_index].text
                })
                
            if is_found and is_substring > 0:
                text_match.append({
                    's_id': tokenized_sentences[sent_index]['s_id'],
                    'src': tokenized_sentences[sent_index]['src'],
                    'tgt': tokenized_sentences[sent_index]['tgt'],
                    'id': texts[text_index].attrib['id'],
                    'text': texts[text_index].text
                })

print('perfect match %d, tokenized match %d, text_match %d' % (len(perfect_match), len(tokenized_match), len(text_match)))
print('tokenized sentences count %d, texts count %d' % (len(tokenized_sentences), len(texts)))
# Out:
# perfect match 20, tokenized match 3, text_match 28
# tokenized sentences count 46, texts count 54

# %%
text_match
# Out:
# [{'id': '034c6aaf-6150-4578-8b89-8adcd1c0bfc3',
#   's_id': 'd0269ae7-a816-4018-bc29-7e5068e2ab44',
#   'src': '......Appellant',
#   'text': '...Appellant',
#   'tgt': '...... अपीलार्थी'},
#  {'id': 'e278a839-b7d4-451e-921e-83f79007d425',
#   's_id': '4e372407-acc7-4774-a836-f02446ef9ed3',
#   'src': '......Respondents',
#   'text': '...Respondents',
#   'tgt': '..... उत्तरदाता'},
#  {'id': 'c8b04270-9e11-4f8a-a344-ea30f7614a70',
#   's_id': 'aca36b8a-674e-4732-80c3-05b050e5ce25',
#   'src': 'Signature Not Verified Digitally signed by',
#   'text': 'Signature Not Verified',
#   'tgt': 'हस्ताक्षर निर्दिष्ट डिजिटल रूप से हस्ताक्षरित नहीं'},
#  {'id': '3d734258-4da1-4672-b9bf-eb958f0b5996',
#   's_id': 'aca36b8a-674e-4732-80c3-05b050e5ce25',
#   'src': 'Signature Not Verified Digitally signed by',
#   'text': 'Digitally signed by',
#   'tgt': 'हस्ताक्षर निर्दिष्ट डिजिटल रूप से हस्ताक्षरित नहीं'},
#  {'id': 'f86be697-4414-4bde-95c6-a5c0295e8b0b',
#   's_id': '1569aa27-d86e-4cd2-b695-3232cc7af476',
#   'src': '13:49:23 IST Reason:',
#   'text': '13:49:23 IST',
#   'tgt': '13:49:23 IST कारण:'},
#  {'id': 'e96004af-a0ba-49e2-b195-5aa38abe328f',
#   's_id': '1569aa27-d86e-4cd2-b695-3232cc7af476',
#   'src': '13:49:23 IST Reason:',
#   'text': 'Reason:',
#   'tgt': '13:49:23 IST कारण:'},
#  {'id': '420039e4-1f00-4e1e-9bb8-055000deba2b',
#   's_id': '358cd68b-7b95-4294-b1b0-7b529a0555e7',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'ए. विवाद की पृष्ठभूमि.'},
#  {'id': '59f5dfad-0293-4e86-935f-15f1d5d5c11d',
#   's_id': '358cd68b-7b95-4294-b1b0-7b529a0555e7',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'ए. विवाद की पृष्ठभूमि.'},
#  {'id': '365ffc44-a486-40f8-b706-828c7ca2a958',
#   's_id': '9e5ae307-dc7e-455a-b7c1-8b961c705e74',
#   'src': 'B Proposal of the Union of India',
#   'text': 'Proposal of the Union of India',
#   'tgt': 'बी भारत संघ के प्रस्ताव'},
#  {'id': '2177cf20-a996-4b27-ac8b-0a8549fb1a47',
#   's_id': '9cb47418-3c89-4eb6-a80d-35b29fd57ac5',
#   'src': 'C Submissions',
#   'text': 'Submissions',
#   'tgt': 'स.  प्रस्तुत करना'},
#  {'id': '653b50ae-c5ae-444e-9442-b6e48590902c',
#   's_id': '887fb932-1449-4552-ba70-9d55971623b4',
#   'src': 'D Consequence of the policy letter dated 25 February 2019',
#   'text': 'Consequence of the policy letter dated 25 February 2019',
#   'tgt': 'डी.  दिनांक 25 फरवरी 2019 के नीति पत्र का परिणाम'},
#  {'id': 'b5240c70-1bcb-405d-ae41-af47e1dcd240',
#   's_id': '146a4bec-5404-4cd6-8bd1-40822d049a1e',
#   'src': 'E Stereotypes and women in the Armed Forces',
#   'text': 'Stereotypes and women in the Armed Forces',
#   'tgt': 'इ. सशस्त्र सेना में ई स्टिरोटाइप और महिलाएं'},
#  {'id': '0a3d8d38-1846-49b0-8fc3-25673e842f2c',
#   's_id': '2fde5398-d524-40ab-9338-902400785d93',
#   'src': 'F Consequence of non-compliance',
#   'text': 'Consequence of non-compliance',
#   'tgt': 'फ.  गैर-उपयोग के परिणाम'},
#  {'id': '59b80289-d09a-42cd-9854-f969213a708b',
#   's_id': 'a6b9c571-3f9e-43e1-93f2-3596323732e2',
#   'src': 'G Blanket restriction on criteria appointments',
#   'text': 'Blanket restriction on criteria appointments',
#   'tgt': 'जी. ब्लैंकेट ने मानदंडों पर भरोसा किया'},
#  {'id': '07bc0a9e-73db-4304-88d3-6503ad0cc302',
#   's_id': '2c769003-7da5-434c-b101-30f045bd4c53',
#   'src': 'H Directions',
#   'text': 'Directions',
#   'tgt': 'ह. दिशाएँ'},
#  {'id': '420039e4-1f00-4e1e-9bb8-055000deba2b',
#   's_id': '47ba17c9-c057-4fda-88c8-7223e6698699',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'अ. विवाद की पृष्ठभूमि.'},
#  {'id': '59f5dfad-0293-4e86-935f-15f1d5d5c11d',
#   's_id': '47ba17c9-c057-4fda-88c8-7223e6698699',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'अ. विवाद की पृष्ठभूमि.'},
#  {'id': 'a7939d8a-b165-4aac-ac7c-0a3ae6128a19',
#   's_id': '4078d96c-c966-4aa9-81f1-d15658633fac',
#   'src': '“(i) Army Postal Service; (ii) Judge Advocate General‟s Department; (iii) Army Education Corps;',
#   'text': '“(i)',
#   'tgt': "'(i) सेना डाक सेवा; (ii) न्यायाधीश महाधिवक्ता विभाग; (iii) सेना शिक्षा कोर;"},
#  {'id': '2cce41d7-358f-496a-b701-b678beabc6f4',
#   's_id': '4078d96c-c966-4aa9-81f1-d15658633fac',
#   'src': '“(i) Army Postal Service; (ii) Judge Advocate General‟s Department; (iii) Army Education Corps;',
#   'text': 'Army Postal Service;',
#   'tgt': "'(i) सेना डाक सेवा; (ii) न्यायाधीश महाधिवक्ता विभाग; (iii) सेना शिक्षा कोर;"},
#  {'id': '30d23055-f2bb-45f0-a557-013634f64faa',
#   's_id': '4078d96c-c966-4aa9-81f1-d15658633fac',
#   'src': '“(i) Army Postal Service; (ii) Judge Advocate General‟s Department; (iii) Army Education Corps;',
#   'text': 'Judge Advocate General‟s Department;',
#   'tgt': "'(i) सेना डाक सेवा; (ii) न्यायाधीश महाधिवक्ता विभाग; (iii) सेना शिक्षा कोर;"},
#  {'id': 'a0addc4f-7c9f-4a58-9f85-d51a33e5aeed',
#   's_id': '4078d96c-c966-4aa9-81f1-d15658633fac',
#   'src': '“(i) Army Postal Service; (ii) Judge Advocate General‟s Department; (iii) Army Education Corps;',
#   'text': 'Army Education Corps;',
#   'tgt': "'(i) सेना डाक सेवा; (ii) न्यायाधीश महाधिवक्ता विभाग; (iii) सेना शिक्षा कोर;"},
#  {'id': '68408be2-3253-41af-bf08-63eff0c31ae2',
#   's_id': 'b4009d00-6f0f-4d71-9486-927e9e66b76d',
#   'src': '(iv) Army Ordinance Corps (Central Ammunition Depots and Material Management); and',
#   'text': 'Army Ordinance Corps (Central Ammunition Depots and Material Management); and',
#   'tgt': '(iv) सेना अध्यादेश कोर (केंद्रीय गोला बारूद डिपो और सामग्री प्रबंधन); और'},
#  {'id': '14486e95-2382-48ff-9556-dfff654c2bf0',
#   's_id': 'c41f100b-2cdc-4b09-b832-d0cab397a52b',
#   'src': '(v) Army Service Corps (Food Scientists and Catering Officers).”',
#   'text': 'Army Service Corps (Food Scientists and Catering',
#   'tgt': '(v) सेना सेवा कोर (खाद्य वैज्ञानिक और खानपान अधिकारी)।'},
#  {'id': 'c542e8fb-799a-468f-9693-5a730bcb7dff',
#   's_id': 'c41f100b-2cdc-4b09-b832-d0cab397a52b',
#   'src': '(v) Army Service Corps (Food Scientists and Catering Officers).”',
#   'text': 'Officers).”',
#   'tgt': '(v) सेना सेवा कोर (खाद्य वैज्ञानिक और खानपान अधिकारी)।'},
#  {'id': '13a9492f-3341-4cae-8301-a45b63fa8e80',
#   's_id': '5e88e19e-c4be-4adc-a037-25202ba8f23e',
#   'src': '1 “PC”',
#   'text': '“PC”',
#   'tgt': '1 पी. सी.'},
#  {'id': '6ce1b6e5-29ec-4a6e-a2d4-de711e66de1b',
#   's_id': '8cd435e9-4d97-4387-b318-231aa32f8f16',
#   'src': '2 “SSCs”',
#   'text': '“SSCs”',
#   'tgt': '2 एसएससी'},
#  {'id': '1e2bdab1-855e-4ccc-acc6-17e3ea980aa9',
#   's_id': 'd09bb71b-40b0-41e7-92ec-ba8259833653',
#   'src': '3 “1950 Act”',
#   'text': '“1950 Act”',
#   'tgt': '3 1950 अधिनियम'},
#  {'id': '6a7b9098-58c4-43ca-85d5-dab5ca2e427e',
#   's_id': '727f9d09-fb54-4ee5-99b1-d7de5aba3976',
#   'src': '4 SRO-',
#   'text': 'SRO-',
#   'tgt': '4 SRO '}]

# %%
perfect_match
# Out:
# [{'id': 'b9094355-2157-4399-8977-bdf6a2c00cf3',
#   's_id': 'c313cd23-6764-483e-bc1b-fff0525b1e2d',
#   'src': 'Reportable',
#   'text': 'Reportable',
#   'tgt': 'रिपोर्ट योग्य'},
#  {'id': 'cdf87c88-9b77-4c2d-82cc-cb570d1c2f1b',
#   's_id': 'a1150d63-a0ff-417d-a4a9-616ba45ceb9b',
#   'src': 'IN THE SUPREME COURT OF INDIA',
#   'text': 'IN THE SUPREME COURT OF INDIA',
#   'tgt': 'भारत के सर्वोच्च न्यायालय में'},
#  {'id': '011e55e0-09a9-4373-97a3-593b864d287b',
#   's_id': '582dd1a5-90c3-4844-8b7d-e9374e46b2fa',
#   'src': 'CIVIL APPELLATE JURISDICTION',
#   'text': 'CIVIL APPELLATE JURISDICTION',
#   'tgt': 'दीवानी अपीलीय क्षेत्राधिकार'},
#  {'id': '0c44e697-6384-49dc-ae01-b090c8dac730',
#   's_id': '996d557b-658b-4803-a61b-08fdfaca92fd',
#   'src': 'Civil Appeal Nos 9367-9369 of 2011',
#   'text': 'Civil Appeal Nos 9367-9369 of 2011',
#   'tgt': '9367 की दीवानी अपील सं. 2011-9369'},
#  {'id': 'd1cc1bb9-2050-4f10-a3bc-3167fd590d01',
#   's_id': '60d82391-6c0d-4912-8a14-fd181600c817',
#   'src': 'The Secretary, Ministry of Defence',
#   'text': 'The Secretary, Ministry of Defence',
#   'tgt': 'रक्षा मंत्रालय के सचिव'},
#  {'id': 'fc244334-ac68-4743-aa48-733454d14a0f',
#   's_id': '5e1e7d4f-d6a5-4f5e-adcc-4d5a750acf2e',
#   'src': 'Versus',
#   'text': 'Versus',
#   'tgt': 'बनाम '},
#  {'id': 'd0a6c4e6-b373-4704-b317-c0f97eb73c8d',
#   's_id': '48dd087c-7a93-47c7-9a5a-ac6bfad069d6',
#   'src': 'Babita Puniya & Ors.',
#   'text': 'Babita Puniya & Ors.',
#   'tgt': 'बबिता पुनिया और ओआरएस।'},
#  {'id': '13755d7d-8f1f-4034-83e4-d159cfe01e3e',
#   's_id': 'eb5b502c-f8ca-4441-ad01-5142e4cc4b26',
#   'src': 'With',
#   'text': 'With',
#   'tgt': 'साथ में '},
#  {'id': '0b99363c-b6e9-499f-b5aa-9bcfeff04af5',
#   's_id': '5f3a3e01-9701-4edf-a6a2-1cc9b5813008',
#   'src': 'Civil Appeal Nos 1127-1128 of 2013',
#   'text': 'Civil Appeal Nos 1127-1128 of 2013',
#   'tgt': '2013 की दीवानी अपील सं. 1127-1128'},
#  {'id': '8e2beeb7-3f45-4cee-81ac-7cc34f335736',
#   's_id': '8c866e29-7d49-46a7-8be6-ba4ee400a256',
#   'src': 'And With',
#   'text': 'And With',
#   'tgt': 'और साथ में '},
#  {'id': 'a1b44059-75ee-471d-9bc3-bcb07a181907',
#   's_id': '8ae0cbda-84c7-43e4-9d68-fd3b702084f9',
#   'src': 'Civil Appeal No. 1210 of 2020',
#   'text': 'Civil Appeal No. 1210 of 2020',
#   'tgt': '2020 की दीवानी अपील सं. 1210'},
#  {'id': '54254ef5-0728-47d3-8416-46ae8801d19f',
#   's_id': '0a1bbd2d-c2cf-41c9-af38-65c86f748eaf',
#   'src': 'SANJAY KUMAR',
#   'text': 'SANJAY KUMAR',
#   'tgt': 'संजय कुमार'},
#  {'id': 'd8fab517-c851-4c2c-bb6a-9b586f02b275',
#   's_id': 'c50a4831-3e48-4b8f-86d3-8ebb1bfce3d2',
#   'src': 'Date: 2020.02.17',
#   'text': 'Date: 2020.02.17',
#   'tgt': 'दिनांक: 2020.02.17'},
#  {'id': '9c0f46ba-1b7e-4ed8-bf36-8772d9aa5ed4',
#   's_id': '3d9c0742-7548-42ce-aa5b-633b419312f4',
#   'src': '1',
#   'text': '1',
#   'tgt': '1'},
#  {'id': 'dca5cd0e-a883-4f12-be07-d92ce0463d42',
#   's_id': '90208c02-81be-42bd-b40b-1cb2dacb4acd',
#   'src': 'JUDGMENT',
#   'text': 'JUDGMENT',
#   'tgt': 'निर्णय '},
#  {'id': '24b924b8-4b24-4272-a38a-7762245ad0a9',
#   's_id': '84dc1a45-5ed5-44ce-83b7-29e956c5316b',
#   'src': 'Dr Dhananjaya Y Chandrachud, J',
#   'text': 'Dr Dhananjaya Y Chandrachud, J',
#   'tgt': 'डॉ धनंजय वाई चंद्रचूड़, जे'},
#  {'id': 'a5126a9b-1cb5-40cc-9e9c-09d4091131b2',
#   's_id': '8953cc82-1b42-488e-a483-a34a57e42e88',
#   'src': 'Index',
#   'text': 'Index',
#   'tgt': 'अनुक्रमणिका'},
#  {'id': 'ed9f4ad1-d34a-4298-9950-e7a14d03c489',
#   's_id': '07211b1e-e703-4c67-b427-036d2d83190e',
#   'src': '2',
#   'text': '2',
#   'tgt': '2'},
#  {'id': '48e8a9f3-b605-4db4-920b-1f5364a0242f',
#   's_id': 'e79e7b98-4014-475e-8866-df78d4233363',
#   'src': 'PART A',
#   'text': 'PART A',
#   'tgt': 'भाग ए'},
#  {'id': '75eba092-6123-4b54-9fc6-d472cf9e734c',
#   's_id': '5743a6b8-11ba-4310-890e-a5f92da87e07',
#   'src': '“12. Ineligibility of females for enrolment or employment.- No female shall be eligible for enrolment or employment in the regular Army, except in such corps, department, branch or other body forming part of, or attached to any portion of, the regular Army as the Central Government may, by notification in the Official Gazette, specify in this behalf.”',
#   'text': '“12. Ineligibility of females for enrolment or employment.- No female shall be eligible for enrolment or employment in the regular Army, except in such corps, department, branch or other body forming part of, or attached to any portion of, the regular Army as the Central Government may, by notification in the Official Gazette, specify in this behalf.”',
#   'tgt': '12. नामांकन या नियोजन के लिए महिलाओं की अयोग्यता।-कोई भी महिला नियमित सेना में नामांकन या रोजगार के लिए पात्र नहीं होगी, सिवाय ऐसे कोर, विभाग, शाखा या अन्य निकाय में, जो केन्द्रीय सरकार के रूप में नियमित सेना के किसी भी हिस्से का हिस्सा बन या उससे जुड़ी हो, राजपत्र में अधिसूचना द्वारा, इस संबंध में निर्दिष्ट नहीं कर सकती है।'}]

# %%
text_match_dict = {}
for elem in text_match:
    if elem['s_id'] not in text_match_dict.keys():
        text_match_dict[elem['s_id']] = [elem]
    else:
        text_match_dict[elem['s_id']].append(elem)

# %%
unique_text_match = []
multiple_text_match_dict = {}

for key in text_match_dict.keys():
    if len(text_match_dict[key]) > 1:
        multiple_text_match_dict[key] = text_match_dict[key]
    else:
        unique_text_match.append(text_match_dict[key][0])

# %%
for key in multiple_text_match_dict.keys():
    doc_text = ''
    for elem in multiple_text_match_dict[key]:
        doc_text = doc_text + ' ' + elem['text']
        
    src_list = [x for x in elem['src'].split(' ') if x]
    src_set  = set(src_list)
    
    doc_list = [x for x in doc_text.split(' ') if x]
    doc_set  = set(doc_list)
    if len(doc_list) <= len(src_list):
        if (len(doc_set) <= len(src_set.intersection(doc_set))) and \
        len(src_set.difference(doc_set)) <= 2:
            unique_text_match.append(multiple_text_match_dict[key][0])
    else:
        print('repeating text')
        print(doc_list, '\n')
        print(src_list, '\n')
# Out:
# repeating text
# ['Background', 'of', 'the', 'dispute', 'Background', 'of', 'the', 'dispute']
#
# ['A', 'Background', 'of', 'the', 'dispute']
#
# repeating text
# ['Background', 'of', 'the', 'dispute', 'Background', 'of', 'the', 'dispute']
#
# ['A', 'Background', 'of', 'the', 'dispute']

# %%
replace_translated(perfect_match, texts)
replace_translated(unique_text_match, texts)

replace_translated(tokenized_match, texts)

# %%
save_document_xml(extracted_dir, document_xml)
save_docx(extracted_dir, filenames, os.path.join(output_dir, "kd2.docx"))

# %%
tokenized_sentences = tokenized_sentences
tags                = texts
texts_matched       = []
placeholders        = []

for sent_index in range(len(tokenized_sentences)):
    for tag_index in range(len(tags)):
        if (tags[tag_index].attrib['id'] not in texts_matched) and \
            (tokenized_sentences[sent_index]['s_id'] not in texts_matched):
            found, tag_text_substring = check_string_status(tags[tag_index], tokenized_sentences[sent_index])
            if found == True:
#                 print('%s <-> %s <--> %r' % (tags[tag_index].text, tokenized_sentences[sent_index]['src'], tag_text_substring))
                if tag_text_substring == None:
                    texts_matched.append(tags[tag_index].attrib['id'])
                    texts_matched.append(tokenized_sentences[sent_index]['s_id'])
                    placeholders.append({
                        's_id': tokenized_sentences[sent_index]['s_id'],
                        'src': tokenized_sentences[sent_index]['src'],
                        'tgt': tokenized_sentences[sent_index]['tgt'],
                        'id': tags[tag_index].attrib['id'],
                        'text': tags[tag_index].text
                    })
                if tag_text_substring == True:
                    texts_matched.append(tokenized_sentences[sent_index]['s_id'])
                    placeholders.append({
                        's_id': tokenized_sentences[sent_index]['s_id'],
                        'src': tokenized_sentences[sent_index]['src'],
                        'tgt': tokenized_sentences[sent_index]['tgt'],
                        'id': tags[tag_index].attrib['id'],
                        'text': tags[tag_index].text
                    })
        else:
            pass
#             print('tag_id %s %s already matched' % (tags[tag_index].attrib['id'], tags[tag_index].text))

'''
    check how much tokenized didn't match
'''
unmatched_tokenized_sentences = []
for tokenized_sentence in tokenized_sentences:
    if tokenized_sentence['s_id'] in texts_matched:
        pass
    else:
        print('unmatched tokenized text:-> %s' % (tokenized_sentence['src']))
        unmatched_tokenized_sentences.append(tokenized_sentence)

print('tokenized sentences, initial: %d, matched: %d, unmatched: %d' % (len(tokenized_sentences), len(placeholders), len(unmatched_tokenized_sentences)))

unmatched_tags = []
for tag in tags:
    if tag.attrib['id'] in texts_matched:
        pass
    else:
        print('unmatched tag text:-> %s' % (tag.text))
        unmatched_tags.append(tag.text)
# Out:
# unmatched tokenized text:-> G Blanket restriction on criteria appointments
# tokenized sentences, initial: 48, matched: 47, unmatched: 1
# unmatched tag text:-> ...Appellant
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:-> ...Respondents
# unmatched tag text:-> Signature Not Verified
# unmatched tag text:-> SANJAY KUMAR
# unmatched tag text:-> 13:49:23 IST
# unmatched tag text:-> Reason:
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:-> Background of the dispute
# unmatched tag text:-> Proposal of the Union of India
# unmatched tag text:-> Submissions
# unmatched tag text:-> Consequence of the policy letter dated 25 February 2019
# unmatched tag text:-> Stereotypes and women in the Armed Forces
# unmatched tag text:-> Consequence of non-compliance
# unmatched tag text:-> Directions
# unmatched tag text:-> A
# unmatched tag text:-> Background of the dispute
# unmatched tag text:-> A quest for equality of opportunity for women seeking Permanent Commissions
# unmatched tag text:-> 1
# unmatched tag text:->  in the Indian Army forms the basis of these appeals. The lead appeal originated in a batch of Writ Petitions which were instituted before the High Court of Delhi in 2003 and 2006.
# unmatched tag text:-> A decade and more spent in litigation, women engaged on Short Service Commissions
# unmatched tag text:-> 2
# unmatched tag text:->  in the Army seek parity with their male counterparts in obtaining PCs. The entry of women in the Army has a chequered history. Section 12 of the Army Act 1950
# unmatched tag text:-> 3
# unmatched tag text:->  contains, in so far as it is material, the following provisions:
# unmatched tag text:-> Pursuant to the power conferred by Section 12, the Union Government issued a notification
# unmatched tag text:-> 4
# unmatched tag text:->  dated 30 January 1992 making women eligible for appointment as officers in the specific branches/cadres of the Army. These were:
# unmatched tag text:-> “(i)
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:-> Army Postal Service;
# unmatched tag text:-> Judge Advocate General‟s Department;
# unmatched tag text:->
# unmatched tag text:->
# unmatched tag text:-> Army Education Corps;
# unmatched tag text:-> Army Ordinance Corps (Central Ammunition Depots and Material Management); and
# unmatched tag text:-> Army Service Corps (Food Scientists and Catering
# unmatched tag text:-> Officers).”
# unmatched tag text:-> “PC”
# unmatched tag text:-> “SSCs”
# unmatched tag text:-> “1950 Act”
# unmatched tag text:-> SRO-

# %%
placeholders
# Out:
# [{'id': '979e0e55-6333-447a-8976-ed8cb8ec82be',
#   's_id': '78844881-23a5-4a12-955e-ddc7b2df8c1d',
#   'src': 'Reportable',
#   'text': 'Reportable',
#   'tgt': 'रिपोर्ट योग्य'},
#  {'id': '3da4ac2a-b07b-4304-80d0-6675c1fa050f',
#   's_id': '0a8ee6fb-bc27-482e-ab47-7169c2acccbb',
#   'src': 'IN THE SUPREME COURT OF INDIA',
#   'text': 'IN THE SUPREME COURT OF INDIA',
#   'tgt': 'भारत के सर्वोच्च न्यायालय में'},
#  {'id': '7758957c-f62a-46bf-9c58-4b1b992bfd38',
#   's_id': '65b11398-df84-4199-aad7-e5eb6646c770',
#   'src': 'CIVIL APPELLATE JURISDICTION',
#   'text': 'CIVIL APPELLATE JURISDICTION',
#   'tgt': 'दीवानी अपीलीय क्षेत्राधिकार'},
#  {'id': '66ea0f20-8970-4ccf-bb53-5a7d74f8b285',
#   's_id': 'fd77ae53-eadd-48a2-8555-3eb00db0583b',
#   'src': 'Civil Appeal Nos 9367-9369 of 2011',
#   'text': 'Civil Appeal Nos 9367-9369 of 2011',
#   'tgt': '9367 की दीवानी अपील सं. 2011-9369'},
#  {'id': 'd88ec932-f403-45d6-a290-1933a471ed27',
#   's_id': 'd30d5348-1829-4ab4-ac3c-19ac102c0411',
#   'src': 'The Secretary, Ministry of Defence',
#   'text': 'The Secretary, Ministry of Defence',
#   'tgt': 'रक्षा मंत्रालय के सचिव'},
#  {'id': 'bc7dd262-cfbf-4894-95dd-7e3de0c3484f',
#   's_id': 'ade6be6f-b35e-42aa-838f-cc7f17be550d',
#   'src': '......Appellant',
#   'text': '...Appellant',
#   'tgt': '...... अपीलार्थी'},
#  {'id': '225f9566-d89f-4222-bb86-5467c29d72c6',
#   's_id': 'f6159c40-e327-4582-9430-a837c04e31da',
#   'src': 'Versus',
#   'text': 'Versus',
#   'tgt': 'बनाम '},
#  {'id': '6519bc7e-78f3-4f04-9fc8-7c0a6972f2d9',
#   's_id': 'f741fe19-fb42-4a44-affe-18c6599493d8',
#   'src': 'Babita Puniya & Ors.',
#   'text': 'Babita Puniya & Ors.',
#   'tgt': 'बबिता पुनिया और अन्य '},
#  {'id': '2f221eb0-8ddb-4791-98b9-9095c6cbbe0c',
#   's_id': 'ce509a60-976a-4494-8a90-779a866cc5fb',
#   'src': '......Respondents',
#   'text': '...Respondents',
#   'tgt': '..... उत्तरदाता '},
#  {'id': '85d2bcff-84ed-4a49-b8c1-d03db1e10d8c',
#   's_id': '2c461301-6ba2-4574-8ed7-eda31d6c3828',
#   'src': 'With',
#   'text': 'With',
#   'tgt': 'साथ '},
#  {'id': '088a0f0c-ee4b-4f3a-8b6d-e79daffbf141',
#   's_id': '3594c9cf-bcc7-4180-aee9-fb7c40d4d29e',
#   'src': 'Civil Appeal Nos 1127-1128 of 2013',
#   'text': 'Civil Appeal Nos 1127-1128 of 2013',
#   'tgt': '2013 की दीवानी अपील सं. 1127-1128'},
#  {'id': '95b4f6b8-d4da-44e8-8956-a2aa9b6e852d',
#   's_id': '8ff09b72-2589-433b-ae27-990f5935103e',
#   'src': 'And With',
#   'text': 'And With',
#   'tgt': 'और साथ में '},
#  {'id': 'dbb3a3e9-685b-4e14-ad98-964efefbdf9a',
#   's_id': '8bbb1c9c-461a-46aa-ad02-01a21c8d2658',
#   'src': 'Civil Appeal No. 1210 of 2020',
#   'text': 'Civil Appeal No. 1210 of 2020',
#   'tgt': '2020 की दीवानी अपील सं. 1210'},
#  {'id': '5be9015e-d5c6-47e6-9f94-394320228392',
#   's_id': 'b67dbd9e-66ba-4df7-aea8-725f166c2f38',
#   'src': 'Signature Not Verified Reason:',
#   'text': 'Signature Not Verified',
#   'tgt': 'हस्ताक्षर अधिसूचित कारण:'},
#  {'id': '91a1e5e2-eef8-44f8-b686-871526c229f2',
#   's_id': 'd43503ef-b374-434c-8492-972e43e502fc',
#   'src': 'Date: 2020.02.17',
#   'text': 'Date: 2020.02.17',
#   'tgt': 'दिनांक: 2020.02.17'},
#  {'id': '28cce3d2-7f12-42ab-a62e-69452a79fec6',
#   's_id': '56f21501-2caf-43e8-9b52-cf0161e72920',
#   'src': 'Digitally signed by',
#   'text': 'Digitally signed by',
#   'tgt': 'द्वारा डिजिटल रूप से'},
#  {'id': 'fd2c4ff9-aab6-4ca8-9b9b-dbb27c4f1653',
#   's_id': '2a8be237-bde3-4de4-834c-726611408627',
#   'src': '1',
#   'text': '1',
#   'tgt': '1'},
#  {'id': '4e51ebad-3ab9-4e86-8ba8-3e0f1ff93f41',
#   's_id': 'f02b6a89-e778-4d8e-9ed0-cccb309e83a1',
#   'src': 'JUDGMENT',
#   'text': 'JUDGMENT',
#   'tgt': 'निर्णय '},
#  {'id': '8c257ac9-0013-463c-be4f-7990a728d2fa',
#   's_id': 'e9d945c0-1e09-48b2-a2ab-bfe9236bbe09',
#   'src': 'Dr Dhananjaya Y Chandrachud, J',
#   'text': 'Dr Dhananjaya Y Chandrachud, J',
#   'tgt': 'डॉ धनंजय वाई चंद्रचूड़, जे'},
#  {'id': '85a87b26-9172-4b81-895b-a2821223d3c4',
#   's_id': 'a4b6fd2d-edc8-4f8e-a192-64d5d1945c6c',
#   'src': 'Index',
#   'text': 'Index',
#   'tgt': 'अनुक्रमणिका'},
#  {'id': 'adea1399-dee1-4fcc-8c53-2ca9942a2c8b',
#   's_id': '39f56767-7831-402c-a445-d1b7a7aa0a28',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'अ. विवाद की पृष्ठभूमि'},
#  {'id': '47f010dc-e520-4e21-a105-cc9d539360ae',
#   's_id': '4142a6f1-99f5-424a-a73e-c65494ed6307',
#   'src': 'B Proposal of the Union of India',
#   'text': 'Proposal of the Union of India',
#   'tgt': 'ब. भारत संघ के प्रस्ताव'},
#  {'id': '35295cfb-c625-4a2a-929b-ea1c6a9dbfc6',
#   's_id': '74bdc4d4-c5f4-47bc-a1f1-c5027a01ec7f',
#   'src': 'C Submissions',
#   'text': 'Submissions',
#   'tgt': 'स. प्रस्तुत करना'},
#  {'id': '276af069-c35f-42c2-81f8-4b99e52861bd',
#   's_id': 'b6fe1f0f-9f37-49ab-8de2-c811a5392396',
#   'src': 'D Consequence of the policy letter dated 25 February 2019',
#   'text': 'Consequence of the policy letter dated 25 February 2019',
#   'tgt': 'द. दिनांक 25 फरवरी 2019 के नीति पत्र का परिणाम'},
#  {'id': '7178e6d1-3d56-4689-af7d-6cc68506b56c',
#   's_id': '7d58e1a6-e603-4695-8378-a31e22e15d2f',
#   'src': 'E Stereotypes and women in the Armed Forces',
#   'text': 'Stereotypes and women in the Armed Forces',
#   'tgt': 'इ. सशस्त्र सेना में पुराने ख्याल और महिलाएं'},
#  {'id': 'c4cb9534-6758-4258-a6ff-1ed8aea7b4c9',
#   's_id': '2ed80d30-6c06-416b-85f6-617b68a8c26d',
#   'src': 'F Consequence of non-compliance',
#   'text': 'Consequence of non-compliance',
#   'tgt': 'फ. गैर-उपयोग के परिणाम'},
#  {'id': '24e6ac1a-8cec-44a4-84b8-ccf754af0370',
#   's_id': '34cc3414-4199-4e18-aa3b-2e68302f4949',
#   'src': 'Blanket restriction on criteria appointments',
#   'text': 'Blanket restriction on criteria appointments',
#   'tgt': 'मानदंड मुलाकात पर प्रतिबंध को भंग करें।'},
#  {'id': 'd375112d-9400-4219-9334-267f67c71cef',
#   's_id': '2330abe8-3e9e-4af0-8e3e-f3e34333d9f0',
#   'src': 'H Directions',
#   'text': 'Directions',
#   'tgt': 'दिशाएँ '},
#  {'id': 'd375112d-9400-4219-9334-267f67c71cef',
#   's_id': '90918bee-26db-4401-99c9-1907444d2e25',
#   'src': 'H Directions',
#   'text': 'Directions',
#   'tgt': 'ह.  दिशाएँ'},
#  {'id': 'a1285d24-f65c-40e1-8348-844d82077857',
#   's_id': '36461ca9-5a00-48ad-a126-d7617780613b',
#   'src': '2',
#   'text': '2',
#   'tgt': '2'},
#  {'id': '7857e70a-57f2-4695-8b24-3bc80240d501',
#   's_id': '88c169ee-06ef-4b5b-9159-2abdf9088d58',
#   'src': 'PART A',
#   'text': 'PART A',
#   'tgt': 'भाग ए'},
#  {'id': 'adea1399-dee1-4fcc-8c53-2ca9942a2c8b',
#   's_id': '13766284-9cc9-44b0-9ac6-28f1e698352b',
#   'src': 'A Background of the dispute',
#   'text': 'Background of the dispute',
#   'tgt': 'A. विवाद की पृष्ठभूमि.'},
#  {'id': '5dbb81b2-46c8-47f7-9a71-21dd02f6b792',
#   's_id': '32c02051-939f-439a-8629-6a1e62f8ae46',
#   'src': '1. A quest for equality of opportunity for women seeking Permanent Commissions in the Indian Army forms the basis of these appeals.',
#   'text': 'A quest for equality of opportunity for women seeking Permanent Commissions',
#   'tgt': '1. भारतीय सेना में स्थायी आयोगों की मांग करने वाली महिलाओं के लिए अवसर की समानता की खोज इन अपीलों का आधार बनती है।'},
#  {'id': '950827dc-3787-4f0a-8a61-4d408a27f7d1',
#   's_id': '61e3833c-f755-42aa-a7e3-cb5f629b94ef',
#   'src': 'The lead appeal originated in a batch of Writ Petitions which were instituted before the High Court of Delhi in 2003 and 2006.',
#   'text': ' in the Indian Army forms the basis of these appeals. The lead appeal originated in a batch of Writ Petitions which were instituted before the High Court of Delhi in 2003 and 2006.',
#   'tgt': 'लीड अपील रिट याचिकाओं के एक बैच में उत्पन्न हुई थी जिसे 2003 और 2006 में दिल्ली उच्च न्यायालय के समक्ष स्थापित किया गया था।'},
#  {'id': 'd085aef6-6fcc-4f97-94ce-12e43fa98ab9',
#   's_id': '2ee15592-1d8c-401a-beff-74590b3decac',
#   'src': '2. A decade and more spent in litigation, women engaged on Short Service Commissions in the Army seek parity with their male counterparts in obtaining PCs. The entry of women in the Army has a chequered history.',
#   'text': 'A decade and more spent in litigation, women engaged on Short Service Commissions',
#   'tgt': '2. मुकदमेबाजी में एक दशक से अधिक समय लगता है, सेना में शॉर्ट सर्विस आयोगों में लगी महिलाओं को PC प्राप्त करने में अपने पुरुष समकक्षों के साथ समानता की तलाश है। सेना में महिलाओं के प्रवेश का एक जांचा-परखा इतिहास है।'},
#  {'id': 'a152288f-c258-43f4-9582-b14acb00092a',
#   's_id': 'b3beb6df-6900-4097-b26c-b7da682f88a4',
#   'src': 'Section 12 of the Army Act 1950 contains, in so far as it is material, the following provisions:',
#   'text': ' contains, in so far as it is material, the following provisions:',
#   'tgt': 'सेना अधिनियम 1950 की धारा 12 में, जहां तक यह सामग्री है, निम्नलिखित प्रावधान हैं:'},
#  {'id': '4a64f008-1cec-4a06-a608-1c279b60936c',
#   's_id': '3b5ddb72-3d1d-419a-90e2-923d4ded16bb',
#   'src': '“12. Ineligibility of females for enrolment or employment.- No female shall be eligible for enrolment or employment in the regular Army, except in such corps, department, branch or other body forming part of, or attached to any portion of, the regular Army as the Central Government may, by notification in the Official Gazette, specify in this behalf.”',
#   'text': '“12. Ineligibility of females for enrolment or employment.- No female shall be eligible for enrolment or employment in the regular Army, except in such corps, department, branch or other body forming part of, or attached to any portion of, the regular Army as the Central Government may, by notification in the Official Gazette, specify in this behalf.”',
#   'tgt': '12. नामांकन या नियोजन के लिए महिलाओं की अयोग्यता।-कोई भी महिला नियमित सेना में नामांकन या रोजगार के लिए पात्र नहीं होगी, सिवाय ऐसे कोर, विभाग, शाखा या अन्य निकाय में, जो केन्द्रीय सरकार के रूप में नियमित सेना के किसी भी हिस्से का हिस्सा बन या उससे जुड़ी हो, राजपत्र में अधिसूचना द्वारा, इस संबंध में निर्दिष्ट नहीं कर सकती है।'},
#  {'id': '012f5be0-5bee-43f8-ab93-8f729cbaedc2',
#   's_id': 'eedaadcc-b069-44a8-9537-655ede9b69f0',
#   'src': '3. Pursuant to the power conferred by Section 12, the Union Government issued a notification dated 30 January 1992 making women eligible for appointment as officers in the specific branches/cadres of the Army.',
#   'text': 'Pursuant to the power conferred by Section 12, the Union Government issued a notification',
#   'tgt': '3. धारा 12 द्वारा प्रदत्त शक्ति के अनुसार, केंद्र सरकार ने 30 जनवरी 1992 को एक अधिसूचना जारी की, जिसमें महिला को सेना की विशिष्ट शाखाओं/संवर्गों में अधिकारियों के रूप में नियुक्ति के लिए पात्र बनाया गया।'},
#  {'id': '102f9874-bca9-4a33-854e-13e70d2a78ec',
#   's_id': '7432e563-a61f-4ed6-91dc-6780284d4e49',
#   'src': 'These were:',
#   'text': ' dated 30 January 1992 making women eligible for appointment as officers in the specific branches/cadres of the Army. These were:',
#   'tgt': 'ये थे:'},
#  {'id': 'a58c75ad-da20-44e7-b08f-fecb0ba921ce',
#   's_id': 'b1073c6e-db68-4f0a-9b3b-4cbae1761a0a',
#   'src': '“(i) Army Postal Service;',
#   'text': '“(i)',
#   'tgt': "'(i) सेना डाक सेवा;"},
#  {'id': 'e803132d-016a-42cc-b8bb-f73117db608e',
#   's_id': '5428c72d-1c61-404c-9b96-63f3b1ae76b9',
#   'src': '(ii) Judge Advocate General‟s Department;',
#   'text': 'Judge Advocate General‟s Department;',
#   'tgt': '(ii) न्यायाधीश महाधिवक्ता का विभाग;'},
#  {'id': '3812afba-92f6-4bd7-a44b-7a47e11a9018',
#   's_id': '4bf901d6-9005-4053-ac48-a87b7d6c68f6',
#   'src': '(iii) Army Education Corps;',
#   'text': 'Army Education Corps;',
#   'tgt': '(iii) सेना शिक्षा कोर'},
#  {'id': '9ba790fe-6ad8-48b2-a63c-8095de5d664e',
#   's_id': '778c45c8-eaf3-4680-8c9e-5f28c0c626ed',
#   'src': '(iv) Army Ordinance Corps (Central Ammunition Depots and Material Management); and',
#   'text': 'Army Ordinance Corps (Central Ammunition Depots and Material Management); and',
#   'tgt': '(iv) सेना अध्यादेश कोर (केंद्रीय गोला बारूद डिपो और सामग्री प्रबंधन); और'},
#  {'id': 'ce94f823-bb5f-4e1e-b2f4-b6f08cea4a05',
#   's_id': 'f2549717-8e98-4167-94b4-b1c8ffc650b5',
#   'src': '(v) Army Service Corps (Food Scientists and Catering Officers).”',
#   'text': 'Army Service Corps (Food Scientists and Catering',
#   'tgt': '(v) सेना सेवा कोर (खाद्य वैज्ञानिक और खानपान अधिकारी)।'},
#  {'id': 'b5d39eb8-2f98-4d3e-baeb-43205a384028',
#   's_id': 'b2075e05-dd7f-4570-a38e-5fab3c47b6c2',
#   'src': '1 “PC”',
#   'text': '“PC”',
#   'tgt': '1 “PC”'},
#  {'id': '18fe0e63-42d2-417f-9949-3f425d0a8410',
#   's_id': '8a06e831-badc-4553-b72f-0de78afd5c1c',
#   'src': '2 “SSCs”',
#   'text': '“SSCs”',
#   'tgt': '2 “SSCs”'},
#  {'id': '11cb8c47-4559-4ed8-b12a-0ebf9c43df3c',
#   's_id': '3770112f-69d0-431b-af22-0918be381fde',
#   'src': '“1950 Act” SRO-',
#   'text': '“1950 Act”',
#   'tgt': '“1950 अधिनियम” एसआरओ'}]

# %%
# replace the target token
for placeholder in placeholders:
    for tag in tags:
        if 'id' in tag.attrib:
            if tag.attrib['id'] == placeholder['id']:
                tag.text = placeholder['tgt']

# %%
save_document_xml(extracted_dir, document_xml)
save_docx(extracted_dir, filenames, os.path.join(output_dir, "kd2.docx"))
